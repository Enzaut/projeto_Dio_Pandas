# %% [markdown]
# <a href="https://colab.research.google.com/github/Enzaut/projeto_Dio_Pandas/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail(
)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 193    Natal 2019-01-02    3.97    1036     2
# 67     Natal 2019-02-14  379.00     852     2
# 190    Natal 2019-01-02   78.78    1035     3
# 69    Recife 2019-01-01   38.83     981     1
# 22   Aracaju 2018-01-01  150.94    1522     1

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485458

# %% [markdown]
# COLUNA DE RECEITA

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head(
)
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08

# %%
df["Receita"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1      1.0
# 1  Aracaju 2018-01-01   14.21    1522     6      6.0
# 2  Aracaju 2018-01-01   71.55    1520     1      1.0
# 3  Aracaju 2018-01-01    3.01    1521     7      7.0
# 4  Aracaju 2018-01-01   24.51    1522     8      8.0

# %%
df["Receita"].max()
# Out:
# 10.000000000000002

# %%
df["Receita"].min()
# Out:
# 1.0

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju      674.0
# Fortaleza    550.0
# Natal        549.0
# Recife       667.0
# Salvador     476.0
# Name: Receita, dtype: float64

# %%
df.sort_values("Receita", ascending=False).head(10)
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde  Receita
# 120  Aracaju 2018-01-01    7.73    1520    10     10.0
# 26   Aracaju 2018-01-01    6.98    1521    10     10.0
# 16   Aracaju 2018-01-01   37.68    1522    10     10.0
# 98   Aracaju 2018-01-01  138.33    1521    10     10.0
# 13   Aracaju 2018-01-01   43.45    1522    10     10.0
# 115  Aracaju 2018-01-01   50.99    1522    10     10.0
# 127  Aracaju 2018-01-01   33.12    1522     9      9.0
# 31   Aracaju 2018-01-01  171.16    1520     9      9.0
# 75   Aracaju 2018-01-01  160.64    1523     9      9.0
# 43   Aracaju 2018-01-01   19.63    1523     9      9.0

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID              int64
# Qtde                int64
# Receita           float64
# dtype: object

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018     775.0
# 2019    2141.0
# Name: Receita, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda
# 111     Natal 2019-01-02  147.35    1037     2      2.0       2019
# 54     Recife 2019-01-01   23.43     982     7      7.0       2019
# 113  Salvador 2019-03-02   18.90    1034     3      3.0       2019
# 51   Salvador 2019-01-01   13.37    1037     2      2.0       2019
# 112    Recife 2019-03-02  133.59     982     1      1.0       2019

# %%
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month,df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 42      Natal 2019-03-02  775.00     854     2      2.0       2019          3
# 69  Fortaleza 2019-01-01  216.65    1003     6      6.0       2019          1
# 84      Natal 2019-01-02   22.99    1036     1      1.0       2019          1
# 23     Recife 2019-01-01   37.51     982     2      2.0       2019          1
# 72      Natal 2018-05-02  612.00     854     4      4.0       2018          5
#
#     dia_venda
# 42          2
# 69          1
# 84          2
# 23          1
# 72          2

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 1     Aracaju 2018-01-01   14.21    1522     6      6.0       2018          1
# 22     Recife 2019-01-01   39.53     983     3      3.0       2019          1
# 174  Salvador 2019-01-02   35.30    1037     1      1.0       2019          1
# 153     Natal 2019-01-02   17.41    1035     2      2.0       2019          1
# 211     Natal 2019-01-02  141.05    1035     3      3.0       2019          1
#
#      dia_venda diferenca_dias
# 1            1         0 days
# 22           1       365 days
# 174          2       366 days
# 153          2       366 days
# 211          2       366 days

# %%
df["Trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 7       Natal 2019-03-18  886.00     853     4      4.0       2019          3
# 32     Recife 2019-01-01   15.93     982     7      7.0       2019          1
# 61   Salvador 2019-01-01    4.54    1036     3      3.0       2019          1
# 16   Salvador 2019-01-01   32.47    1036     2      2.0       2019          1
# 116     Natal 2019-01-02   41.78    1034     3      3.0       2019          1
#
#      dia_venda diferenca_dias  Trimestre_venda
# 7           18       441 days                1
# 32           1       365 days                1
# 61           1       365 days                1
# 16           1       365 days                1
# 116          2       366 days                1

# %%
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) &(df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 82       Natal 2019-03-07  868.00     854     3      3.0       2019
# 130  Fortaleza 2019-03-02   12.36     983     4      4.0       2019
# 111   Salvador 2019-03-02  147.35    1037     2      2.0       2019
# 136  Fortaleza 2019-03-02   39.09     982     4      4.0       2019
# 74       Natal 2019-03-10  303.00     854     3      3.0       2019
# 75       Natal 2019-03-30  706.00     854     2      2.0       2019
# 121     Recife 2019-03-02   41.55     981     3      3.0       2019
# 138     Recife 2019-03-02  150.38     983     6      6.0       2019
# 7        Natal 2019-03-18  886.00     853     4      4.0       2019
# 119   Salvador 2019-03-02  136.37    1034     2      2.0       2019
# 109  Fortaleza 2019-03-02   18.90     982     6      6.0       2019
# 129   Salvador 2019-03-02  125.66    1037     1      1.0       2019
# 126  Fortaleza 2019-03-02   41.87     980     8      8.0       2019
# ...

# %% [markdown]
# VISUALIZAÇÃO DE DADOS

# %%
df["LojaID"]. value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
df["LojaID"].value_counts(ascending=False).plot.barh()
# Out:
# <Axes: >

# %%
df["LojaID"].value_counts(ascending=True).plot.bar();

# %%
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()
# Out:
# <Axes: ylabel='Receita'>

# %%
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas")
# Out:
# Text(0, 0.5, 'Total Vendas')

# %%
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas")
# Out:
# Text(0, 0.5, 'Total Vendas')

# %%
plt.style.use("ggplot")

# %%
df.groupby(df["mes_venda"])["Qtde"].sum().plot(title = "Total produtos vendidos por mes")
plt.xlabel("Mes")
plt.ylabel("Total Produtos Vendidos")
plt.legend()

# %%
df.groupby(df["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "*")
plt.xlabel("Mes")
plt.ylabel("Total Produtos Vendidos")
plt.legend()

# %%
plt.hist(df["Qtde"],color="magenta")
# Out:
# (array([191., 193., 221.,  85.,  54.,  61.,  38.,  31.,  14.,   6.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x=df_2019["dia_venda"], y = df_2019["Receita"])
